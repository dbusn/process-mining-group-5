# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import datetime as datetime

# %% [markdown]
# ### Data preparation

# %%
df_train = pd.read_csv("bpi2017_train.csv", parse_dates = ['time:timestamp'])
df_val = pd.read_csv("bpi2017_val.csv", parse_dates = ['time:timestamp'])
df_test = pd.read_csv("bpi2017_test.csv", parse_dates = ['time:timestamp'])

# The default name indicating the case ID is case:concept:name
# concept:name is the event
# time:timestamp is the corresponding timestamp
# Load the datasets, sort them on case and consequently timestamp, then reset the index
df_train = df_train.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()
df_val = df_val.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()
df_test = df_test.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()

# Remove obsolete columns
df_train = df_train.drop(['index', 'Unnamed: 0'], axis = 1)
df_val = df_val.drop(['index', 'Unnamed: 0'], axis = 1)
df_test = df_test.drop(['index', 'Unnamed: 0'], axis = 1)

# %% [markdown]
# # 1. Calculate the time difference

# %%
# Cumulative sum function to be used later
def CumSum(lists):
    # Returns the cumulative sum of a list
    length = len(lists)
    cu_list = [sum(lists[0: x: 1]) for x in range(0, length + 1)]
    return cu_list[1: ]

# %%
def time_difference(df):
    # Calculate time difference between each row
    df['time_diff'] = df['time:timestamp'].diff().dt.total_seconds()
    # Set the time difference of the 1st row to 0 as it's currently NaN
    df.at[0, 'time_diff'] = 0
    # Count number of steps per process
    length_per_case_List = df.groupby(['case:concept:name'])['time_diff'].count().tolist()

    # Using the cumulative sum we get all the positions that are a first step in a process
    # And then the time difference can be set to 0
    position_lst = CumSum(length_per_case_List)
    for i in tqdm(position_lst):
        df.at[i, 'time_diff'] = 0
    # For Loop mysteriously creates an empty row at the end of the df, gotta delete it
    df = df.iloc[: -1]

    # Unzip the position list to get the number of each steps of each process, make that into a list
    step_in_process = []
    for x in tqdm(length_per_case_List):
        for y in range(x):
            step_in_process.append(y + 1)
    # Assign position number to each row/process
    df['position'] = step_in_process
    return df

# %%
# Apply the above changes to all dataframes
# The warnings are obsolete, it's because it uses .at which is considerably faster than .loc
df_train = time_difference(df_train)
df_val = time_difference(df_val)
df_test = time_difference(df_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16308/16308 [00:00<00:00, 68212.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16308/16308 [00:00<00:00, 329334.07it/s]
# /tmp/ipykernel_15270/3504450715.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['position'] = step_in_process
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4078/4078 [00:00<00:00, 73859.13it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4078/4078 [00:00<00:00, 360600.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 751/751 [00:00<00:00, 49090.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 751/751 [00:00<00:00, 351514.60it/s]

# %% [markdown]
# # 2. Baseline Time Prediction (Only on Training Dataset)

# %%
# Get the list of position number
step_in_process_train = df_train['position'].tolist()
# Calculate mean time difference grouped by position based on the number of cases
mean_time_lst = df_train.groupby('position')['time_diff'].mean().tolist()

# Create the predicted time column per entry using the mean time difference
pred_time_lst_train = [mean_time_lst[j - 1] for j in step_in_process_train]
df_train['baseline_predicted_time'] = pred_time_lst_train
df_train
# Out:
#              Action org:resource            concept:name  EventOrigin  \
# 0           Created       User_1    A_Create Application  Application
# 1       statechange       User_1             A_Submitted  Application
# 2           Created       User_1          W_Handle leads     Workflow
# 3           Deleted       User_1          W_Handle leads     Workflow
# 4           Created       User_1  W_Complete application     Workflow
# ...             ...          ...                     ...          ...
# 620621     Obtained      User_68  W_Validate application     Workflow
# 620622  statechange      User_68              O_Accepted        Offer
# 620623  statechange      User_68               A_Pending  Application
# 620624      Deleted      User_68  W_Validate application     Workflow
# 620625  statechange      User_68             O_Cancelled        Offer
#
#                        EventID lifecycle:transition  \
# 0       Application_1000158214             complete
# 1          ApplState_277536765             complete
# 2           Workitem_176988109             schedule
# 3           Workitem_895982768             withdraw
# 4          Workitem_1409452454             schedule
# ...                        ...                  ...
# 620621      Workitem_715332932               resume
# 620622    OfferState_287854721             complete
# 620623    ApplState_1161629338             complete
# 620624     Workitem_1093600680             complete
# 620625   OfferState_1418043985             complete
#
#                          time:timestamp     case:LoanGoal  \
# 0      2016-06-02 10:14:26.844000+00:00  Home improvement
# 1      2016-06-02 10:14:26.885000+00:00  Home improvement
# 2      2016-06-02 10:14:27.227000+00:00  Home improvement
# 3      2016-06-02 10:15:36.752000+00:00  Home improvement
# 4      2016-06-02 10:15:36.764000+00:00  Home improvement
# ...                                 ...               ...
# 620621 2016-04-26 09:22:34.654000+00:00  Home improvement
# 620622 2016-04-26 09:23:27.987000+00:00  Home improvement
# 620623 2016-04-26 09:23:28.009000+00:00  Home improvement
# 620624 2016-04-26 09:23:28.012000+00:00  Home improvement
# 620625 2016-04-26 09:23:28.036000+00:00  Home improvement
#
#        case:ApplicationType       case:concept:name  ...  NumberOfTerms  \
# 0                New credit  Application_1000158214  ...            NaN
# 1                New credit  Application_1000158214  ...            NaN
# 2                New credit  Application_1000158214  ...            NaN
# 3                New credit  Application_1000158214  ...            NaN
# 4                New credit  Application_1000158214  ...            NaN
# ...                     ...                     ...  ...            ...
# 620621           New credit   Application_610205010  ...            NaN
# 620622           New credit   Application_610205010  ...            NaN
# 620623           New credit   Application_610205010  ...            NaN
# 620624           New credit   Application_610205010  ...            NaN
# 620625           New credit   Application_610205010  ...            NaN
#
#         Accepted  MonthlyCost Selected  CreditScore OfferedAmount  \
# 0            NaN          NaN      NaN          NaN           NaN
# 1            NaN          NaN      NaN          NaN           NaN
# 2            NaN          NaN      NaN          NaN           NaN
# 3            NaN          NaN      NaN          NaN           NaN
# 4            NaN          NaN      NaN          NaN           NaN
# ...          ...          ...      ...          ...           ...
# 620621       NaN          NaN      NaN          NaN           NaN
# 620622       NaN          NaN      NaN          NaN           NaN
# 620623       NaN          NaN      NaN          NaN           NaN
# 620624       NaN          NaN      NaN          NaN           NaN
# 620625       NaN          NaN      NaN          NaN           NaN
#
#                 OfferID  time_diff position  baseline_predicted_time
# 0                   NaN      0.000        1                 0.000000
# 1                   NaN      0.041        2                 0.108810
# 2                   NaN      0.342        3                 0.246913
# 3                   NaN     69.525        4              2336.961114
# 4                   NaN      0.012        5               101.363755
# ...                 ...        ...      ...                      ...
# 620621              NaN   6159.402       67             24760.097749
# 620622  Offer_772484790     53.333       68             25855.859743
# 620623              NaN      0.022       69             28523.590462
# 620624              NaN      0.003       70             35405.497539
# 620625  Offer_731638418      0.024       71             37967.609182
#
# [620626 rows x 22 columns]

# %% [markdown]
# # 3. Baseline Case Prediction (only on the training dataset)

# %%
position_df = df_train.groupby('position').agg(pd.Series.mode)['concept:name'].to_frame()
df_train = pd.merge(df_train, position_df, on='position')
df_train
# Out:
#              Action org:resource        concept:name_x  EventOrigin  \
# 0           Created       User_1  A_Create Application  Application
# 1           Created      User_71  A_Create Application  Application
# 2           Created       User_1  A_Create Application  Application
# 3           Created       User_1  A_Create Application  Application
# 4           Created       User_7  A_Create Application  Application
# ...             ...          ...                   ...          ...
# 620621  statechange     User_118           O_Cancelled        Offer
# 620622  statechange     User_118           O_Cancelled        Offer
# 620623  statechange     User_118           O_Cancelled        Offer
# 620624  statechange     User_118           O_Cancelled        Offer
# 620625  statechange     User_118           O_Cancelled        Offer
#
#                        EventID lifecycle:transition  \
# 0       Application_1000158214             complete
# 1       Application_1000311556             complete
# 2       Application_1000334415             complete
# 3       Application_1000339879             complete
# 4       Application_1000474975             complete
# ...                        ...                  ...
# 620621   OfferState_2104946863             complete
# 620622   OfferState_1671093436             complete
# 620623    OfferState_816623561             complete
# 620624    OfferState_475329857             complete
# 620625    OfferState_826409251             complete
#
#                          time:timestamp           case:LoanGoal  \
# 0      2016-06-02 10:14:26.844000+00:00        Home improvement
# 1      2016-04-04 15:56:37.675000+00:00                     Car
# 2      2016-09-15 16:39:17.758000+00:00  Other, see explanation
# 3      2016-03-17 12:57:10.159000+00:00  Existing loan takeover
# 4      2016-06-16 15:37:24.412000+00:00  Other, see explanation
# ...                                 ...                     ...
# 620621 2016-06-07 08:35:37.303000+00:00     Remaining debt home
# 620622 2016-06-07 08:35:37.314000+00:00     Remaining debt home
# 620623 2016-06-07 08:35:37.327000+00:00     Remaining debt home
# 620624 2016-06-07 08:35:37.596000+00:00     Remaining debt home
# 620625 2016-06-07 08:35:37.609000+00:00     Remaining debt home
#
#        case:ApplicationType       case:concept:name  ...  Accepted  \
# 0                New credit  Application_1000158214  ...       NaN
# 1                New credit  Application_1000311556  ...       NaN
# 2                New credit  Application_1000334415  ...       NaN
# 3                New credit  Application_1000339879  ...       NaN
# 4                New credit  Application_1000474975  ...       NaN
# ...                     ...                     ...  ...       ...
# 620621           New credit  Application_2037628374  ...       NaN
# 620622           New credit  Application_2037628374  ...       NaN
# 620623           New credit  Application_2037628374  ...       NaN
# 620624           New credit  Application_2037628374  ...       NaN
# 620625           New credit  Application_2037628374  ...       NaN
#
#         MonthlyCost  Selected CreditScore  OfferedAmount           OfferID  \
# 0               NaN       NaN         NaN            NaN               NaN
# 1               NaN       NaN         NaN            NaN               NaN
# 2               NaN       NaN         NaN            NaN               NaN
# 3               NaN       NaN         NaN            NaN               NaN
# 4               NaN       NaN         NaN            NaN               NaN
# ...             ...       ...         ...            ...               ...
# 620621          NaN       NaN         NaN            NaN  Offer_1158976722
# 620622          NaN       NaN         NaN            NaN  Offer_1596032809
# 620623          NaN       NaN         NaN            NaN  Offer_1305081611
# 620624          NaN       NaN         NaN            NaN   Offer_966701358
# 620625          NaN       NaN         NaN            NaN   Offer_354631205
#
#         time_diff  position baseline_predicted_time        concept:name_y
# 0           0.000         1                   0.000  A_Create Application
# 1           0.000         1                   0.000  A_Create Application
# 2           0.000         1                   0.000  A_Create Application
# 3           0.000         1                   0.000  A_Create Application
# 4           0.000         1                   0.000  A_Create Application
# ...           ...       ...                     ...                   ...
# 620621      0.012       176                   0.012           O_Cancelled
# 620622      0.011       177                   0.011           O_Cancelled
# 620623      0.013       178                   0.013           O_Cancelled
# 620624      0.269       179                   0.269           O_Cancelled
# 620625      0.013       180                   0.013           O_Cancelled
#
# [620626 rows x 23 columns]

# %% [markdown]
# # 4. Apply Above Calculated Mean Time to Validation and Test datasets

# %%
def apply_time_prediction(df):
    # Get the list of position number
    step_in_process = df['position'].tolist()

    # Create the predicted time column per entry using the mean time difference
    # If some position numbers are not shown in the training dataset, its predicted time will be 0
    pred_time_lst = []
    for j in step_in_process:
        if j <= len(mean_time_lst):
            pred_time_lst.append(mean_time_lst[j - 1])
        else:
            pred_time_lst.append(0)
    df['baseline_predicted_time'] = pred_time_lst
    return df

# %%
# Apply the above changes to all dataframes
df_val = apply_time_prediction(df_val)
df_test = apply_time_prediction(df_test)

# %% [markdown]
# # 5. Apply Baseline Case prediction to Validation and Test datasets

# %%
def apply_case_prediction(df: pd.DataFrame) -> pd.DataFrame:
    # Merge the dataframe with position with the dataframe prediction is applied to
    df = pd.merge(df, position_df, on='position')
    
    # Sort values by timestamp, like in the original dataset
    df.sort_values(by=['time:timestamp'], inplace=True)
    
    # Rename the column labels due to applying merge
    df.rename(columns = {"concept:name_y":"baseline_action_pred", "concept:name_x":"concept:name"}, inplace=True)
    
    return df

# %%
df_val = apply_case_prediction(df_val)
df_test = apply_case_prediction(df_test)

# %% [markdown]
# ### Dataset preview

# %%
df_train
# Out:
#              Action org:resource        concept:name_x  EventOrigin  \
# 0           Created       User_1  A_Create Application  Application
# 1           Created      User_71  A_Create Application  Application
# 2           Created       User_1  A_Create Application  Application
# 3           Created       User_1  A_Create Application  Application
# 4           Created       User_7  A_Create Application  Application
# ...             ...          ...                   ...          ...
# 620621  statechange     User_118           O_Cancelled        Offer
# 620622  statechange     User_118           O_Cancelled        Offer
# 620623  statechange     User_118           O_Cancelled        Offer
# 620624  statechange     User_118           O_Cancelled        Offer
# 620625  statechange     User_118           O_Cancelled        Offer
#
#                        EventID lifecycle:transition  \
# 0       Application_1000158214             complete
# 1       Application_1000311556             complete
# 2       Application_1000334415             complete
# 3       Application_1000339879             complete
# 4       Application_1000474975             complete
# ...                        ...                  ...
# 620621   OfferState_2104946863             complete
# 620622   OfferState_1671093436             complete
# 620623    OfferState_816623561             complete
# 620624    OfferState_475329857             complete
# 620625    OfferState_826409251             complete
#
#                          time:timestamp           case:LoanGoal  \
# 0      2016-06-02 10:14:26.844000+00:00        Home improvement
# 1      2016-04-04 15:56:37.675000+00:00                     Car
# 2      2016-09-15 16:39:17.758000+00:00  Other, see explanation
# 3      2016-03-17 12:57:10.159000+00:00  Existing loan takeover
# 4      2016-06-16 15:37:24.412000+00:00  Other, see explanation
# ...                                 ...                     ...
# 620621 2016-06-07 08:35:37.303000+00:00     Remaining debt home
# 620622 2016-06-07 08:35:37.314000+00:00     Remaining debt home
# 620623 2016-06-07 08:35:37.327000+00:00     Remaining debt home
# 620624 2016-06-07 08:35:37.596000+00:00     Remaining debt home
# 620625 2016-06-07 08:35:37.609000+00:00     Remaining debt home
#
#        case:ApplicationType       case:concept:name  ...  Accepted  \
# 0                New credit  Application_1000158214  ...       NaN
# 1                New credit  Application_1000311556  ...       NaN
# 2                New credit  Application_1000334415  ...       NaN
# 3                New credit  Application_1000339879  ...       NaN
# 4                New credit  Application_1000474975  ...       NaN
# ...                     ...                     ...  ...       ...
# 620621           New credit  Application_2037628374  ...       NaN
# 620622           New credit  Application_2037628374  ...       NaN
# 620623           New credit  Application_2037628374  ...       NaN
# 620624           New credit  Application_2037628374  ...       NaN
# 620625           New credit  Application_2037628374  ...       NaN
#
#         MonthlyCost  Selected CreditScore  OfferedAmount           OfferID  \
# 0               NaN       NaN         NaN            NaN               NaN
# 1               NaN       NaN         NaN            NaN               NaN
# 2               NaN       NaN         NaN            NaN               NaN
# 3               NaN       NaN         NaN            NaN               NaN
# 4               NaN       NaN         NaN            NaN               NaN
# ...             ...       ...         ...            ...               ...
# 620621          NaN       NaN         NaN            NaN  Offer_1158976722
# 620622          NaN       NaN         NaN            NaN  Offer_1596032809
# 620623          NaN       NaN         NaN            NaN  Offer_1305081611
# 620624          NaN       NaN         NaN            NaN   Offer_966701358
# 620625          NaN       NaN         NaN            NaN   Offer_354631205
#
#         time_diff  position baseline_predicted_time        concept:name_y
# 0           0.000         1                   0.000  A_Create Application
# 1           0.000         1                   0.000  A_Create Application
# 2           0.000         1                   0.000  A_Create Application
# 3           0.000         1                   0.000  A_Create Application
# 4           0.000         1                   0.000  A_Create Application
# ...           ...       ...                     ...                   ...
# 620621      0.012       176                   0.012           O_Cancelled
# 620622      0.011       177                   0.011           O_Cancelled
# 620623      0.013       178                   0.013           O_Cancelled
# 620624      0.269       179                   0.269           O_Cancelled
# 620625      0.013       180                   0.013           O_Cancelled
#
# [620626 rows x 23 columns]

# %%
df_val
# Out:
#             Action org:resource            concept:name  EventOrigin  \
# 2297       Created       User_1    A_Create Application  Application
# 6375   statechange       User_1             A_Submitted  Application
# 10453      Created       User_1          W_Handle leads     Workflow
# 14531      Deleted       User_1          W_Handle leads     Workflow
# 18609      Created       User_1  W_Complete application     Workflow
# ...            ...          ...                     ...          ...
# 74150  statechange       User_1             O_Cancelled        Offer
# 78046      Deleted       User_1     W_Call after offers     Workflow
# 86711  statechange       User_1             A_Cancelled  Application
# 90242  statechange       User_1             O_Cancelled        Offer
# 93639      Deleted       User_1     W_Call after offers     Workflow
#
#                       EventID lifecycle:transition  \
# 2297   Application_1878239836             complete
# 6375      ApplState_649299817             complete
# 10453     Workitem_1693495632             schedule
# 14531     Workitem_1080257214             withdraw
# 18609     Workitem_1531288681             schedule
# ...                       ...                  ...
# 74150    OfferState_516860315             complete
# 78046     Workitem_1599009653            ate_abort
# 86711     ApplState_338161915             complete
# 90242    OfferState_341732870             complete
# 93639     Workitem_1959899819            ate_abort
#
#                         time:timestamp     case:LoanGoal case:ApplicationType  \
# 2297  2016-01-01 13:35:26.422000+00:00  Home improvement           New credit
# 6375  2016-01-01 13:35:26.463000+00:00  Home improvement           New credit
# 10453 2016-01-01 13:35:26.664000+00:00  Home improvement           New credit
# 14531 2016-01-01 13:36:30.982000+00:00  Home improvement           New credit
# 18609 2016-01-01 13:36:30.993000+00:00  Home improvement           New credit
# ...                                ...               ...                  ...
# 74150 2016-11-13 07:00:36.337000+00:00  Home improvement           New credit
# 78046 2016-11-13 07:00:36.346000+00:00  Home improvement           New credit
# 86711 2016-11-13 07:00:49.818000+00:00  Home improvement           New credit
# 90242 2016-11-13 07:00:49.840000+00:00  Home improvement           New credit
# 93639 2016-11-13 07:00:49.849000+00:00  Home improvement           New credit
#
#             case:concept:name  ...  Accepted  MonthlyCost  Selected  \
# 2297   Application_1878239836  ...       NaN          NaN       NaN
# 6375   Application_1878239836  ...       NaN          NaN       NaN
# 10453  Application_1878239836  ...       NaN          NaN       NaN
# 14531  Application_1878239836  ...       NaN          NaN       NaN
# 18609  Application_1878239836  ...       NaN          NaN       NaN
# ...                       ...  ...       ...          ...       ...
# 74150   Application_132220187  ...       NaN          NaN       NaN
# 78046   Application_132220187  ...       NaN          NaN       NaN
# 86711  Application_1792327676  ...       NaN          NaN       NaN
# 90242  Application_1792327676  ...       NaN          NaN       NaN
# 93639  Application_1792327676  ...       NaN          NaN       NaN
#
#       CreditScore  OfferedAmount          OfferID    time_diff  position  \
# 2297          NaN            NaN              NaN        0.000         1
# 6375          NaN            NaN              NaN        0.041         2
# 10453         NaN            NaN              NaN        0.201         3
# 14531         NaN            NaN              NaN       64.318         4
# 18609         NaN            NaN              NaN        0.011         5
# ...           ...            ...              ...          ...       ...
# 74150         NaN            NaN  Offer_869706358        0.025        19
# 78046         NaN            NaN              NaN        0.009        20
# 86711         NaN            NaN              NaN  2247927.100        22
# 90242         NaN            NaN  Offer_230690584        0.022        23
# 93639         NaN            NaN              NaN        0.009        24
#
#       baseline_predicted_time    baseline_action_pred
# 2297                 0.000000    A_Create Application
# 6375                 0.108810             A_Submitted
# 10453                0.246913          W_Handle leads
# 14531             2336.961114          W_Handle leads
# 18609              101.363755  W_Complete application
# ...                       ...                     ...
# 74150           178269.342986     W_Call after offers
# 78046           141001.874388     W_Call after offers
# 86711           146835.274929     W_Call after offers
# 90242           106112.924149  W_Validate application
# 93639            92745.077935  W_Validate application
#
# [155506 rows x 23 columns]

# %%
df_test
# Out:
#             Action org:resource             concept:name  EventOrigin  \
# 458        Created       User_1     A_Create Application  Application
# 1209   statechange       User_1              A_Submitted  Application
# 1960       Created       User_1           W_Handle leads     Workflow
# 590        Created      User_41     A_Create Application  Application
# 1341       Created      User_41   W_Complete application     Workflow
# ...            ...          ...                      ...          ...
# 28406      Deleted     User_131  W_Call incomplete files     Workflow
# 28429      Created     User_131   W_Validate application     Workflow
# 28451     Obtained     User_131   W_Validate application     Workflow
# 28472  statechange     User_131             A_Validating  Application
# 28492     Released     User_131   W_Validate application     Workflow
#
#                      EventID lifecycle:transition  \
# 458    Application_837911105             complete
# 1209    ApplState_1692094008             complete
# 1960     Workitem_1100633268             schedule
# 590    Application_912681536             complete
# 1341     Workitem_1334591020             schedule
# ...                      ...                  ...
# 28406    Workitem_1308647312            ate_abort
# 28429    Workitem_1339594215             schedule
# 28451    Workitem_1697785565                start
# 28472   ApplState_1576288280             complete
# 28492     Workitem_997581455              suspend
#
#                         time:timestamp           case:LoanGoal  \
# 458   2016-11-14 05:57:57.461000+00:00  Existing loan takeover
# 1209  2016-11-14 05:57:59.458000+00:00  Existing loan takeover
# 1960  2016-11-14 05:57:59.981000+00:00  Existing loan takeover
# 590   2016-11-14 08:12:30.523000+00:00        Home improvement
# 1341  2016-11-14 08:12:30.536000+00:00        Home improvement
# ...                                ...                     ...
# 28406 2017-02-01 14:00:30.259000+00:00  Existing loan takeover
# 28429 2017-02-01 14:00:30.272000+00:00  Existing loan takeover
# 28451 2017-02-01 14:00:30.275000+00:00  Existing loan takeover
# 28472 2017-02-01 14:00:30.347000+00:00  Existing loan takeover
# 28492 2017-02-01 14:01:24.191000+00:00  Existing loan takeover
#
#       case:ApplicationType      case:concept:name  ...  Accepted  MonthlyCost  \
# 458             New credit  Application_837911105  ...       NaN          NaN
# 1209            New credit  Application_837911105  ...       NaN          NaN
# 1960            New credit  Application_837911105  ...       NaN          NaN
# 590             New credit  Application_912681536  ...       NaN          NaN
# 1341            New credit  Application_912681536  ...       NaN          NaN
# ...                    ...                    ...  ...       ...          ...
# 28406           New credit  Application_637536789  ...       NaN          NaN
# 28429           New credit  Application_637536789  ...       NaN          NaN
# 28451           New credit  Application_637536789  ...       NaN          NaN
# 28472           New credit  Application_637536789  ...       NaN          NaN
# 28492           New credit  Application_637536789  ...       NaN          NaN
#
#        Selected CreditScore  OfferedAmount OfferID  time_diff  position  \
# 458         NaN         NaN            NaN     NaN      0.000         1
# 1209        NaN         NaN            NaN     NaN      1.997         2
# 1960        NaN         NaN            NaN     NaN      0.523         3
# 590         NaN         NaN            NaN     NaN      0.000         1
# 1341        NaN         NaN            NaN     NaN      0.013         2
# ...         ...         ...            ...     ...        ...       ...
# 28406       NaN         NaN            NaN     NaN   5193.446        77
# 28429       NaN         NaN            NaN     NaN      0.013        78
# 28451       NaN         NaN            NaN     NaN      0.003        79
# 28472       NaN         NaN            NaN     NaN      0.072        80
# 28492       NaN         NaN            NaN     NaN     53.844        81
#
#       baseline_predicted_time     baseline_action_pred
# 458                  0.000000     A_Create Application
# 1209                 0.108810              A_Submitted
# 1960                 0.246913           W_Handle leads
# 590                  0.000000     A_Create Application
# 1341                 0.108810              A_Submitted
# ...                       ...                      ...
# 28406            29014.518989  W_Call incomplete files
# 28429            43444.314986  W_Call incomplete files
# 28451            26900.300938  W_Call incomplete files
# 28472            32291.172272  W_Call incomplete files
# 28492            24587.081815  W_Call incomplete files
#
# [28706 rows x 23 columns]
