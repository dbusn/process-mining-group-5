# %%
import numpy as np
import pandas as pd
import re
from tqdm import tqdm
import datetime as datetime

# %%
df_train = pd.read_csv("bpi2017_train.csv", parse_dates = ['time:timestamp'])
df_val = pd.read_csv("bpi2017_val.csv", parse_dates = ['time:timestamp'])
df_test = pd.read_csv("bpi2017_test.csv", parse_dates = ['time:timestamp'])

# The default name indicating the case ID is case:concept:name
# concept:name is the event
# time:timestamp is the corresponding timestamp
# Load the datasets, sort them on case and consequently timestamp, then reset the index
df_train = df_train.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()
df_val = df_val.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()
df_test = df_test.sort_values(by = ['case:concept:name', 'time:timestamp']).reset_index()

# Remove obsolete columns
df_train = df_train.drop(['index', 'Unnamed: 0'], axis = 1)
df_val = df_val.drop(['index', 'Unnamed: 0'], axis = 1)
df_test = df_test.drop(['index', 'Unnamed: 0'], axis = 1)

# %% [markdown]
# # 1. Calculate the time difference

# %%
# Cumulative sum function to be used later
def CumSum(lists):
    # Returns the cumulative sum of a list
    length = len(lists)
    cu_list = [sum(lists[0: x: 1]) for x in range(0, length + 1)]
    return cu_list[1: ]

# %%
def time_difference(df):
    # Calculate time difference between each row
    df['time_diff'] = df['time:timestamp'].diff().dt.total_seconds()
    # Set the time difference of the 1st row to 0 as it's currently NaN
    df.at[0, 'time_diff'] = 0
    # Count number of steps per process
    length_per_case_List = df.groupby(['case:concept:name'])['time_diff'].count().tolist()

    # Using the cumulative sum we get all the positions that are a first step in a process
    # And then the time difference can be set to 0
    position_lst = CumSum(length_per_case_List)
    for i in tqdm(position_lst):
        df.at[i, 'time_diff'] = 0
    # For Loop mysteriously creates an empty row at the end of the df, gotta delete it
    df = df.iloc[: -1]

    # Unzip the position list to get the number of each steps of each process, make that into a list
    step_in_process = []
    for x in tqdm(length_per_case_List):
        for y in range(x):
            step_in_process.append(y + 1)
    # Assign position number to each row/process
    df['position'] = step_in_process
    return df

# %%
# Apply the above changes to all dataframes
# The warnings are obsolete, it's because it uses .at which is considerably faster than .loc
df_train = time_difference(df_train)
df_val = time_difference(df_val)
df_test = time_difference(df_test)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 16308/16308 [00:00<00:00, 52537.89it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 16308/16308 [00:00<00:00, 192965.60it/s]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|███████████████████████████████████████████████████████████████████████████| 4078/4078 [00:00<00:00, 55190.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 4078/4078 [00:00<00:00, 226974.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 751/751 [00:00<00:00, 41832.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 751/751 [00:00<00:00, 175219.58it/s]

# %% [markdown]
# # 2. Baseline Time Prediction (Only on Training Dataset)

# %%
# Get the list of position number
step_in_process_train = df_train['position'].tolist()
# Calculate mean time difference grouped by position based on the number of cases
mean_time_lst = df_train.groupby('position')['time_diff'].mean().tolist()

# Create the predicted time column per entry using the mean time difference
pred_time_lst_train = [mean_time_lst[j - 1] for j in step_in_process_train]
df_train['baseline_predicted_time'] = pred_time_lst_train
df_train
# Out:
#              Action org:resource            concept:name  EventOrigin  \
# 0           Created       User_1    A_Create Application  Application
# 1       statechange       User_1             A_Submitted  Application
# 2           Created       User_1          W_Handle leads     Workflow
# 3           Deleted       User_1          W_Handle leads     Workflow
# 4           Created       User_1  W_Complete application     Workflow
# ...             ...          ...                     ...          ...
# 620439     Obtained      User_68  W_Validate application     Workflow
# 620440  statechange      User_68              O_Accepted        Offer
# 620441  statechange      User_68               A_Pending  Application
# 620442      Deleted      User_68  W_Validate application     Workflow
# 620443  statechange      User_68             O_Cancelled        Offer
#
#                        EventID lifecycle:transition  \
# 0       Application_1000086665             complete
# 1          ApplState_161925113             complete
# 2           Workitem_747707399             schedule
# 3          Workitem_1030261128             withdraw
# 4          Workitem_1127124826             schedule
# ...                        ...                  ...
# 620439      Workitem_715332932               resume
# 620440    OfferState_287854721             complete
# 620441    ApplState_1161629338             complete
# 620442     Workitem_1093600680             complete
# 620443   OfferState_1418043985             complete
#
#                          time:timestamp           case:LoanGoal  \
# 0      2016-08-03 15:57:21.673000+00:00  Other, see explanation
# 1      2016-08-03 15:57:21.734000+00:00  Other, see explanation
# 2      2016-08-03 15:57:21.963000+00:00  Other, see explanation
# 3      2016-08-03 15:58:28.286000+00:00  Other, see explanation
# 4      2016-08-03 15:58:28.293000+00:00  Other, see explanation
# ...                                 ...                     ...
# 620439 2016-04-26 09:22:34.654000+00:00        Home improvement
# 620440 2016-04-26 09:23:27.987000+00:00        Home improvement
# 620441 2016-04-26 09:23:28.009000+00:00        Home improvement
# 620442 2016-04-26 09:23:28.012000+00:00        Home improvement
# 620443 2016-04-26 09:23:28.036000+00:00        Home improvement
#
#        case:ApplicationType       case:concept:name  ...  NumberOfTerms  \
# 0                New credit  Application_1000086665  ...            NaN
# 1                New credit  Application_1000086665  ...            NaN
# 2                New credit  Application_1000086665  ...            NaN
# 3                New credit  Application_1000086665  ...            NaN
# 4                New credit  Application_1000086665  ...            NaN
# ...                     ...                     ...  ...            ...
# 620439           New credit   Application_610205010  ...            NaN
# 620440           New credit   Application_610205010  ...            NaN
# 620441           New credit   Application_610205010  ...            NaN
# 620442           New credit   Application_610205010  ...            NaN
# 620443           New credit   Application_610205010  ...            NaN
#
#         Accepted  MonthlyCost Selected  CreditScore OfferedAmount  \
# 0            NaN          NaN      NaN          NaN           NaN
# 1            NaN          NaN      NaN          NaN           NaN
# 2            NaN          NaN      NaN          NaN           NaN
# 3            NaN          NaN      NaN          NaN           NaN
# 4            NaN          NaN      NaN          NaN           NaN
# ...          ...          ...      ...          ...           ...
# 620439       NaN          NaN      NaN          NaN           NaN
# 620440       NaN          NaN      NaN          NaN           NaN
# 620441       NaN          NaN      NaN          NaN           NaN
# 620442       NaN          NaN      NaN          NaN           NaN
# 620443       NaN          NaN      NaN          NaN           NaN
#
#                 OfferID  time_diff position  baseline_predicted_time
# 0                   NaN      0.000        1                 0.000000
# 1                   NaN      0.061        2                 0.105229
# 2                   NaN      0.229        3                 0.242584
# 3                   NaN     66.323        4              2470.953376
# 4                   NaN      0.007        5               103.429894
# ...                 ...        ...      ...                      ...
# 620439              NaN   6159.402       67             24102.327326
# 620440  Offer_772484790     53.333       68             21609.747173
# 620441              NaN      0.022       69             27145.051865
# 620442              NaN      0.003       70             28502.377932
# 620443  Offer_731638418      0.024       71             35267.134356
#
# [620444 rows x 22 columns]

# %% [markdown]
# # 3. Apply Above Calculated Mean Time to Validation and Test Set

# %%
def apply_prediction(df):
    # Get the list of position number
    step_in_process = df['position'].tolist()

    # Create the predicted time column per entry using the mean time difference
    # If some position numbers are not shown in the training dataset, its predicted time will be 0
    pred_time_lst = []
    for j in step_in_process:
        if j <= len(mean_time_lst):
            pred_time_lst.append(mean_time_lst[j - 1])
        else:
            pred_time_lst.append(0)
    df['baseline_predicted_time'] = pred_time_lst
    return df

# %%
# Apply the above changes to all dataframes
df_val = apply_prediction(df_val)
df_test = apply_prediction(df_test)
df_val
# Out:
#              Action org:resource            concept:name  EventOrigin  \
# 0           Created      User_71    A_Create Application  Application
# 1           Created      User_71  W_Complete application     Workflow
# 2          Obtained      User_71  W_Complete application     Workflow
# 3       statechange      User_71               A_Concept  Application
# 4       statechange      User_71              A_Accepted  Application
# ...             ...          ...                     ...          ...
# 155683  statechange      User_39            A_Validating  Application
# 155684     Released      User_39  W_Validate application     Workflow
# 155685  statechange     User_116              O_Accepted        Offer
# 155686  statechange     User_116               A_Pending  Application
# 155687      Deleted     User_116  W_Validate application     Workflow
#
#                        EventID lifecycle:transition  \
# 0       Application_1000311556             complete
# 1          Workitem_1212746755             schedule
# 2            Workitem_95061077                start
# 3         ApplState_1508577231             complete
# 4          ApplState_189615352             complete
# ...                        ...                  ...
# 155683    ApplState_1662533710             complete
# 155684      Workitem_621404938              suspend
# 155685   OfferState_1906154041             complete
# 155686       ApplState_9557204             complete
# 155687      Workitem_721869470            ate_abort
#
#                          time:timestamp     case:LoanGoal  \
# 0      2016-04-04 15:56:37.675000+00:00               Car
# 1      2016-04-04 15:56:37.688000+00:00               Car
# 2      2016-04-04 15:56:37.693000+00:00               Car
# 3      2016-04-04 15:56:37.696000+00:00               Car
# 4      2016-04-04 16:06:29.479000+00:00               Car
# ...                                 ...               ...
# 155683 2016-06-20 14:52:05.816000+00:00  Home improvement
# 155684 2016-06-20 14:52:25.340000+00:00  Home improvement
# 155685 2016-06-20 14:58:31.014000+00:00  Home improvement
# 155686 2016-06-20 14:58:31.020000+00:00  Home improvement
# 155687 2016-06-20 14:58:31.022000+00:00  Home improvement
#
#        case:ApplicationType       case:concept:name  ...  NumberOfTerms  \
# 0                New credit  Application_1000311556  ...            NaN
# 1                New credit  Application_1000311556  ...            NaN
# 2                New credit  Application_1000311556  ...            NaN
# 3                New credit  Application_1000311556  ...            NaN
# 4                New credit  Application_1000311556  ...            NaN
# ...                     ...                     ...  ...            ...
# 155683           New credit    Application_60999665  ...            NaN
# 155684           New credit    Application_60999665  ...            NaN
# 155685           New credit    Application_60999665  ...            NaN
# 155686           New credit    Application_60999665  ...            NaN
# 155687           New credit    Application_60999665  ...            NaN
#
#         Accepted  MonthlyCost Selected  CreditScore OfferedAmount  \
# 0            NaN          NaN      NaN          NaN           NaN
# 1            NaN          NaN      NaN          NaN           NaN
# 2            NaN          NaN      NaN          NaN           NaN
# 3            NaN          NaN      NaN          NaN           NaN
# 4            NaN          NaN      NaN          NaN           NaN
# ...          ...          ...      ...          ...           ...
# 155683       NaN          NaN      NaN          NaN           NaN
# 155684       NaN          NaN      NaN          NaN           NaN
# 155685       NaN          NaN      NaN          NaN           NaN
# 155686       NaN          NaN      NaN          NaN           NaN
# 155687       NaN          NaN      NaN          NaN           NaN
#
#                  OfferID  time_diff position  baseline_predicted_time
# 0                    NaN      0.000        1                 0.000000
# 1                    NaN      0.013        2                 0.105229
# 2                    NaN      0.005        3                 0.242584
# 3                    NaN      0.003        4              2470.953376
# 4                    NaN    591.783        5               103.429894
# ...                  ...        ...      ...                      ...
# 155683               NaN      0.070       37             32463.565499
# 155684               NaN     19.524       38             30576.940455
# 155685  Offer_1603549424    365.674       39             31179.482374
# 155686               NaN      0.006       40             28837.622489
# 155687               NaN      0.002       41             32509.704270
#
# [155688 rows x 22 columns]

# %%
df_test
# Out:
#             Action org:resource            concept:name  EventOrigin  \
# 0          Created       User_1    A_Create Application  Application
# 1      statechange       User_1             A_Submitted  Application
# 2          Created       User_1          W_Handle leads     Workflow
# 3          Deleted       User_1          W_Handle leads     Workflow
# 4          Created       User_1  W_Complete application     Workflow
# ...            ...          ...                     ...          ...
# 28701      Deleted       User_1     W_Call after offers     Workflow
# 28702      Created       User_1     W_Call after offers     Workflow
# 28703  statechange       User_1             A_Cancelled  Application
# 28704  statechange       User_1             O_Cancelled        Offer
# 28705      Deleted       User_1     W_Call after offers     Workflow
#
#                      EventID lifecycle:transition  \
# 0      Application_610717758             complete
# 1       ApplState_1960150929             complete
# 2         Workitem_684900503             schedule
# 3         Workitem_954760450             withdraw
# 4        Workitem_1752703538             schedule
# ...                      ...                  ...
# 28701    Workitem_1894495253            ate_abort
# 28702    Workitem_1671270331             schedule
# 28703    ApplState_318084843             complete
# 28704   OfferState_560115325             complete
# 28705     Workitem_476001650             withdraw
#
#                         time:timestamp           case:LoanGoal  \
# 0     2016-11-19 23:12:05.325000+00:00                     Car
# 1     2016-11-19 23:12:06.411000+00:00                     Car
# 2     2016-11-19 23:12:06.690000+00:00                     Car
# 3     2016-11-19 23:12:47.428000+00:00                     Car
# 4     2016-11-19 23:12:47.435000+00:00                     Car
# ...                                ...                     ...
# 28701 2016-12-20 06:32:24.316000+00:00  Existing loan takeover
# 28702 2016-12-20 06:32:24.326000+00:00  Existing loan takeover
# 28703 2017-01-16 07:00:30.429000+00:00  Existing loan takeover
# 28704 2017-01-16 07:00:30.449000+00:00  Existing loan takeover
# 28705 2017-01-16 07:00:30.457000+00:00  Existing loan takeover
#
#       case:ApplicationType      case:concept:name  ...  NumberOfTerms  \
# 0               New credit  Application_610717758  ...            NaN
# 1               New credit  Application_610717758  ...            NaN
# 2               New credit  Application_610717758  ...            NaN
# 3               New credit  Application_610717758  ...            NaN
# 4               New credit  Application_610717758  ...            NaN
# ...                    ...                    ...  ...            ...
# 28701           New credit  Application_999632431  ...            NaN
# 28702           New credit  Application_999632431  ...            NaN
# 28703           New credit  Application_999632431  ...            NaN
# 28704           New credit  Application_999632431  ...            NaN
# 28705           New credit  Application_999632431  ...            NaN
#
#        Accepted  MonthlyCost Selected  CreditScore OfferedAmount  \
# 0           NaN          NaN      NaN          NaN           NaN
# 1           NaN          NaN      NaN          NaN           NaN
# 2           NaN          NaN      NaN          NaN           NaN
# 3           NaN          NaN      NaN          NaN           NaN
# 4           NaN          NaN      NaN          NaN           NaN
# ...         ...          ...      ...          ...           ...
# 28701       NaN          NaN      NaN          NaN           NaN
# 28702       NaN          NaN      NaN          NaN           NaN
# 28703       NaN          NaN      NaN          NaN           NaN
# 28704       NaN          NaN      NaN          NaN           NaN
# 28705       NaN          NaN      NaN          NaN           NaN
#
#                OfferID    time_diff position  baseline_predicted_time
# 0                  NaN        0.000        1                 0.000000
# 1                  NaN        1.086        2                 0.105229
# 2                  NaN        0.279        3                 0.242584
# 3                  NaN       40.738        4              2470.953376
# 4                  NaN        0.007        5               103.429894
# ...                ...          ...      ...                      ...
# 28701              NaN   331831.284       19            180456.850270
# 28702              NaN        0.010       20            137202.070216
# 28703              NaN  2334486.103       21            108489.723106
# 28704  Offer_872978767        0.020       22            146098.017933
# 28705              NaN        0.008       23            107605.707584
#
# [28706 rows x 22 columns]

# %%
position_lst = list(range(1, len(mean_time_lst) + 1))
df_prediction = pd.DataFrame(position_lst)
df_prediction['predicted_time'] = mean_time_lst
df_prediction = df_prediction.rename(columns = {0: 'position'})
df_prediction
# Out:
#      position  predicted_time
# 0           1        0.000000
# 1           2        0.105229
# 2           3        0.242584
# 3           4     2470.953376
# 4           5      103.429894
# ..        ...             ...
# 175       176   292506.206000
# 176       177        0.007000
# 177       178        0.008000
# 178       179        0.140500
# 179       180        0.011000
#
# [180 rows x 2 columns]

# %%
df_prediction.to_csv('baseline_time.csv')
