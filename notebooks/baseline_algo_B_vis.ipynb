# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df_prediction = pd.read_csv("baseline_time.csv")
ax = sns.lineplot(data = df_prediction, x = "position", y = "predicted_time");
ax.set_xlabel('Position')
ax.set_ylabel('Predicted Time')
ax.set_title('Baseline Predicted Time', size = 20)
# Out:
# Text(0.5, 1.0, 'Baseline Predicted Time')
